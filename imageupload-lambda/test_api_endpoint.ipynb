# %%
import requests, io
from PIL import Image

# %%
API_ENDPOINT = 'https://jftj2ol1za.execute-api.us-east-1.amazonaws.com/test'
image_path = 'cfu_positive.jpg'

# %%
im = Image.open(image_path)
# Create in-memory JPEG
buffer = io.BytesIO()
im.save(buffer, format="JPEG")

# Make request to the endpoint
r = requests.post(url=API_ENDPOINT, data=buffer.getvalue())
# Here is the request
Image.open(io.BytesIO(r.content))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1510x1485>
